# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
x = np.array([1,8])
y = np.array([3,10])
plt.plot(x,y)
plt.show()
